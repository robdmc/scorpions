# %%
import easier as ezr
import pandas as pd
import lifelines as ll
# %config Completer.use_jedi = False

# %%
sheet = ezr.GSheet('scorpions_rob_david', 'Export E1')
df = sheet.to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-2-df2150c3d863> in <module>
# ----> 1 sheet = ezr.GSheet('scorpions_rob_david', 'Export E1')
#       2 df = sheet.to_dataframe()
#
# ~/rob/repos/easier/easier/gsheet.py in __init__(self, doc, sheet)
#      75         self._sheet = None
#      76         self._df_cache = {}
# ---> 77         self.document = self.api.open(doc)
#      78         self.sheet = self.document.worksheet(sheet)
#      79
#
# ~/miniconda/envs/viz/lib/python3.6/site-packages/gspread/client.py in open(self, title)
#     117             properties = finditem(
#     118                 lambda x: x['name'] == title,
# --> 119                 self.list_spreadsheet_files(title),
#     120             )
#     121
#
# ~/miniconda/envs/viz/lib/python3.6/site-packages/gspread/client.py in list_spreadsheet_files(self, title)
# ...
